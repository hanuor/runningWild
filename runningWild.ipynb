# %%
# Sample Markdown

# %% [markdown]
# # Sample Markdown

# %%
### SAMAMMAMAMA

# %%
print('dfd')
# Out:
# dfd

# %%
a = 54

# %%
s=45
print(s+a)
# Out:
# 99

# %% [markdown]
# # This is a tes
# #### This is a test
